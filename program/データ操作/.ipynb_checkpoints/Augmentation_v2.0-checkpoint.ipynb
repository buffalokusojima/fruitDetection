# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os
from PIL import Image, ImageOps, ImageEnhance
import glob
import shutil
import sys

# %%
# 変更する部分

# %%
# 入力とする画像のフォルダを指定。種類までのパスをコピペしてください。
# すべての種類を一気にやりたい場合は*\imageまでのパスをコピペしてください
# inputImageFolderPath = '..\学習データ\混合データ\品種\image'
inputImageFolderPath = r'\\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ'

# すべての種類を一気にやる場合はTrueに、1つの種類のみやる場合はFalseにしてください。
# allFruits = True
allFruits = False

# 何の画像処理をさせるかを決めてください。前から順に処理されます。
# 0:彩度変更, 1:コントラスト変更, 2:明度変更, 3:シャープネス変更, 4:拡大・縮小, 5:上下反転, 6:左右反転, 7:90度回転, 8:270度回転
processList = [5]

# %%
# 変更しない部分

# %%
# 出力のフォルダを指定。いじらなくていいはずです。
outputRoot = '..\学習データ\水増しデータ\混合データ'
# 入力テキストフォルダ。いじらない。
inputTextFolderPath = inputImageFolderPath.replace('image', 'annotation')

# 彩度調整パラメータ。1.0以上で明るく、1.0未満で暗く
saturationRatio = 1.5

# コントラスト調整パラメータ。1.0以上で明るく、1.0未満で暗く
contrastRatio = 1.5

# 明度調整パラメータ。1.0以上で明るく、1.0未満で暗く
brightnessRatio = 1.5

# シャープネス調整パラメータ。1.0以上でくっきり、1.0未満でぼやける
sharpnessRatio = 1.5

# 大きさ調整パラメータ。縦横がこの倍率で大きくなります。
expansionRatio = 1.2

# %%
# 各種関数

# %%
def makeFolder(root, folderName, imageFile):
    outputPath = os.path.join(root, folderName)
    if not os.path.exists(outputPath):
        os.mkdir(outputPath)
    
    
    outputPath = os.path.join(outputPath, imageFile.split('\\')[-5])
    if not os.path.exists(outputPath):
        os.mkdir(outputPath)
    
    outputAnnotationPath = os.path.join(outputPath, "annotation")
    if not os.path.exists(outputAnnotationPath):
        os.mkdir(outputAnnotationPath)
    outputImagePath = os.path.join(outputPath, "image")
    if not os.path.exists(outputImagePath):
        os.mkdir(outputImagePath)
    
    imagePathList = imageFile.split('\\')
    
    outputAnnotationPath = os.path.join(outputAnnotationPath, imagePathList[-3])
    if not os.path.exists(outputAnnotationPath):
        os.mkdir(outputAnnotationPath)
    outputImagePath = os.path.join(outputImagePath, imagePathList[-3])
    if not os.path.exists(outputImagePath):
        os.mkdir(outputImagePath)
    
    outputAnnotationPath = os.path.join(outputAnnotationPath, imagePathList[-2])
    if not os.path.exists(outputAnnotationPath):
        os.mkdir(outputAnnotationPath)
        outputAnnotationPath = os.path.join(outputAnnotationPath, 'classes.txt')
        with open(outputAnnotationPath, mode = 'w') as f:
            f.write("")
    outputImagePath = os.path.join(outputImagePath, imagePathList[-2])
    if not os.path.exists(outputImagePath):
        os.mkdir(outputImagePath)

        
def decideOutputFolderName():
    outputFolderName = ""
    for process in processList:
        if process == 0:
            outputFolderName += "彩度" + str(saturationRatio)
        elif process == 1:
            outputFolderName += "コントラスト" + str(contrastRatio)
        elif process == 2:
            outputFolderName += "明度" + str(brightnessRatio)
        elif process == 3:
            outputFolderName += "シャープネス" + str(sharpnessRatio)
        elif process == 4:
            outputFolderName += "大きさ" + str(expansionRatio)
        elif process == 5:
            outputFolderName += "上下反転"
        elif process == 6:
            outputFolderName += "左右反転"
        elif process == 7:
            outputFolderName += "90度回転"
        elif process == 8:
            outputFolderName += "270度回転"
    return outputFolderName

def copy(inputObject, outputObject):
    if os.path.exists(inputObject):
        shutil.copy(inputObject, outputObject)

def processing(image, coorList):
    for process in processList:
        if process == 0:
            image = changeSaturation(image, saturationRatio)
        elif process == 1:
            image= changeContrast(image, contrastRatio)
        elif process == 2:
            image = changeBrightness(image, brightnessRatio)
        elif process == 3:
            image = changeSharpness(image, sharpnessRatio)
        elif process == 4:
            image, coorList = changeSize(image, coorList, expansionRatio)
        elif process == 5:
            image, coorList = flipVertical(image, coorList)
        elif process == 6:
            image, coorList = flipHorizontal(image, coorList)
        elif process == 7:
            image, coorList = rotation90(image, coorList)
        elif process == 8:
            image, coorList = rotation270(image, coorList)
    return image, coorList

def changeSaturation(image, ratio):
    saturation = ImageEnhance.Color(image)
    return saturation.enhance(ratio)

def changeContrast(image, ratio):
    contrast = ImageEnhance.Contrast(image)
    return contrast.enhance(ratio)

def changeBrightness(image, ratio):
    brightness = ImageEnhance.Brightness(image)
    return brightness.enhance(ratio)

def changeSharpness(image, ratio):
    sharpness = ImageEnhance.Sharpness(image)
    return sharpness.enhance(ratio)

def changeSize(image, coorList, ratio):
    w, h = image.size
    resizedImage = image.resize((int(w * ratio), int(h * ratio)))
    
    resizedCoorList = []
    for oneCoorList in coorList:
        xmin = int(oneCoorList[0])
        ymin = int(oneCoorList[1])
        xmax = int(oneCoorList[2])
        ymax = int(oneCoorList[3])
        resizedCoorList.append([str(int(xmin * ratio)), str(int(ymin * ratio)), str(int(xmax * ratio)), str(int(ymax * ratio)), oneCoorList[4]])
    return resizedImage, resizedCoorList

def flipVertical(image, coorList):
    flippedImage = ImageOps.flip(image)
    
    flippedCoorList = []
    w, h = image.size
    for oneCoorList in coorList:
        xmin = int(oneCoorList[0])
        ymin = int(oneCoorList[1])
        xmax = int(oneCoorList[2])
        ymax = int(oneCoorList[3])
        flippedCoorList.append([str(xmin), str(h - ymax), str(xmax), str(h - ymin), oneCoorList[4]])
    return flippedImage, flippedCoorList

def flipHorizontal(image, coorList):
    mirrorImage = ImageOps.mirror(image)
    
    mirrorCoorList = []
    w, h = image.size
    for oneCoorList in coorList:
        xmin = int(oneCoorList[0])
        ymin = int(oneCoorList[1])
        xmax = int(oneCoorList[2])
        ymax = int(oneCoorList[3])
        mirrorCoorList.append([str(w - xmax), str(ymin), str(w - xmin), str(ymax), oneCoorList[4]])
    return mirrorImage, mirrorCoorList

def rotation90(image, coorList):
    rotatedImage = image.rotate(90, expand = True)
    
    rotatedCoorList = []
    w, h = image.size
    for oneCoorList in coorList:
        xmin = int(oneCoorList[0])
        ymin = int(oneCoorList[1])
        xmax = int(oneCoorList[2])
        ymax = int(oneCoorList[3])
        rotatedCoorList.append([str(ymin), str(w - xmax), str(ymax), str(w - xmin), oneCoorList[4]])
    return rotatedImage, rotatedCoorList

def rotation270(image, coorList):
    rotatedImage = image.rotate(270, expand = True)
    
    rotatedCoorList = []
    w, h = image.size
    for oneCoorList in coorList:
        xmin = int(oneCoorList[0])
        ymin = int(oneCoorList[1])
        xmax = int(oneCoorList[2])
        ymax = int(oneCoorList[3])
        rotatedCoorList.append([str(h - ymax), str(xmin), str(h - ymin), str(xmax), oneCoorList[4]])
    return rotatedImage, rotatedCoorList

# %%
# 実行するところ

# %%
outputFolderName = decideOutputFolderName()

imageName = r'\*\*.jpg'
if allFruits:
    imageName = r'\*\*\*.jpg'

### folder作成
for inputImageFile in glob.glob(inputImageFolderPath + imageName):
    splitInputImageFile = inputImageFile.split('\\')
    if 'Thumbs.jpg' in splitInputImageFile[-1]:
        continue
    makeFolder(outputRoot, outputFolderName, inputImageFile)

### 画像ファイル取得
errorList = []
try:
    splitinputImageFolderPath = inputImageFolderPath.split('\\')
    outputImageFolderPath = os.path.join(outputRoot, outputFolderName, splitinputImageFolderPath[-3], splitinputImageFolderPath[-2], splitinputImageFolderPath[-1])
    for image in glob.glob(inputImageFolderPath + imageName):
        splitImage = image.split('\\')
        if 'Thumbs.jpg' in splitImage[-1]:
            continue
        print(image)
        originalImage = Image.open(image).convert("RGB")
        originalText = image.replace("image", "annotation").replace(".jpg", ".txt")
        coorList = []
        if os.path.exists(originalText):
            with open(originalText) as f:
                for s_line in f:
                    if len(s_line.split(',')) == 1:
                        pass
                    else:
                        coorList.append(s_line.split(','))

   
        ### 画像水増し処理
        processedImage, processedCoorList = processing(originalImage, coorList)

        ### 出力
        outputImageFile = os.path.join(outputRoot, outputFolderName, splitImage[-5], splitImage[-4], splitImage[-3], splitImage[-2], splitImage[-1])
        processedImage.save(outputImageFile)
        outputTextFile = outputImageFile.replace("image", "annotation").replace(".jpg", ".txt")
        with open(outputTextFile, mode = 'w') as f:
            for oneCoorList in processedCoorList:
                f.write(oneCoorList[0] + "," + oneCoorList[1] + "," + oneCoorList[2] + "," + oneCoorList[3] + "," + oneCoorList[4])
except Exception as e:
    print(e)
    errorList.append(image)
finally:
    print(errorList)
    print(len(errorList))

#TODO:trycatchは動くものの、処理が続かない。
# Out:
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\1.sato1.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\10.img10051927485.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\10_092F-005s1.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\113.010705sat.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\116.20120307roji-01.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\119.satonishiki.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\11_002-00210sq0.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\125.00120012-thumb-360x360-75.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\126.maxresdefault.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\12_seikaokoku_s-fs3055.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\131.maxresdefault.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\135.20120220saku-02.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\138.satonisiki_roji1kg_1.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\139.sd1_7c43708b311240f9f5046c49029f73922dcfdbb7.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\13_1003-100320200707-CP.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\141.20120220saku-03.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\142.cherry01_201804.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\143.sakura-1.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\14_1003-100320200707-CP.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\155.sakura2018_4_01.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\156.maxresdefault.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\15_satouni_500g.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\16.kodawarisatonisiki500g1.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\161.20120220saku-23.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\162.tokusenb500g-main.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\164.poiuioooooi.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\166.20160409_8cdfe2.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\16_L1.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\17.sato2--770x513.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\176.20130220ksaku-21.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\17_IMG_2828.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\180.32103138.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\182.image11.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\183.o0607108014790008716.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\18_1.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\196.imgrc0068015782.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\197.19sk-ea515-m2.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\19_slider-satonishiki.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\1_main1_068-00017gv_578_578.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\2.8dc1c0880954357085bab2513151a577.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\200.sd1_64b65a42655b6ebc078d2bc237f84d9f0d676856.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\207.satounishiki.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\20_satounishiki_san.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\21.160225-hsnm-01.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\21_img_01.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\223.mmhouse_1.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\224.E46510000272_3.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\229.20150522bs01.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\22_img_02.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\234.ygsak-yutaka111.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\237.onshitsu.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\23_22780.3.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\24.cherry_01.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\243.20130220ksaku-26.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\24_jc1503056.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\25.190212-str-02.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\256.190322-haha-07.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\25_jc1503060.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\261.imgrc0069681479.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\269.slider-satonishiki3.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\26_jc1503058.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\27.20120220saku-16.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\274.o1440108014480538488.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\27_1701200906.g_400-w_g.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\28.sakuranbo-kaon02.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\280.sakuranbo-top750.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\287.satounishiki1n1.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\28_c_limit,w_1000.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\299.sakuranbo_satou.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\29_103673129.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\2_97327_97327.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\3.asahi_cherry00.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\30_103673129_o1.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\31_136477485.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\32_ygo_27722_T1.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\33_2.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\34.20120307roji-25.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\34_02.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\35_satou-1.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\36_69-web_photo2c.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\37_FT-J-013.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\3_gr87_main-01.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\45.20120213saku-16.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\49.sat640.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\4_653dc973e76f8573b55f0e865d451a6a.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\5.cherry_image01.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\54.l551898_1.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\5_6aa91bffd14cdaf644cd0130b6781c89.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\6.skuranbo2012_02.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\60.20160701-3.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\62.satos1--770x513.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\64.sakuranbo2019.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\67.20120307roji-26.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\68.2017roji05.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\6_ecg2006011200001-p1.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\7_001.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\8.13701407791.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\81.imgrc0064342009.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\84.saku_01_sato_1.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\85.saku_0520_tilyo2.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\8_002.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\9.sato1--770x513.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\94.saiseiki01.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\95.satounishiki.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\1_佐藤錦\9_fa204556.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\1.c-53.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\10.01726gassan.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\102.66-298b62324763e2de055fdcd98355fd6f.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\104.DfvNwZuUYAARQYn.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\105.o0640048013045495566.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\106.hqdefault.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\107.main1_24pr_a_waifu2x_art_noise1_scale_tta_1_waifu2x_art_noise1_scale_tta_1_578_578.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\11.45309727.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\110.02510_2010_0703_IMG_0024.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\111.02509_2010_0703_IMG_0017.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\112.A8946-0186_03.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\113.Gassannishiki20s.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\116.05869_2013_0718_IMG_8997.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\117.0617185524_5ee9e88c1d8a4.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\118.119643427_o3.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\119.1gas0627c1.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\12.jag-14-2.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\120.cherry04.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\122.acbd7543306c08e8e25ad3b00d011b58.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\126.DglfGGnU8AAmTGU.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\127.jam_su11-min.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\128.NKZ112.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\13.DC-pP0TUwAAu0NO.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\130.20160628082551c2c.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\131.imgrc0069877891.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\132.092F-011t.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\133.DSC_9338.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\134.19954407_o1.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\135.3.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\136.1.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\137.srbgn01.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\139.05870_2013_0718_IMG_9006.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\14.gr441-i2.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\144.DgNt5A9U8AI7zHV.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\145.A8946-0186_01.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\146.06006_2013_0719_IMG_9572.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\147.gr441-b.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\148.25380015916.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\15.102F-018s1.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\152.IMG_1416-e1530166505123.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\153.winday19992002-img640x480-1593717303tcgxwk18920.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\154.img_cache_a_22952_1_1511010622_jpg.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\156._1_width308.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\16.imgrc0067837632.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\161.Dh6Sk83UwAUOPaL.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\162.gassan.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\164.ohashi-cherryfarm_20200414172355_5.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\165.119643427_o1.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\167.item_21.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\168.img07.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\17.12133668421.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\171.gassan_4l2l_500g_02.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\172.main1_gassan_578_578.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\174.06004_2013_0719_IMG_9570.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\176.02511_2010_0703_IMG_0095.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\18.p001.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\182.c817-p.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\19.gassannisiki1k1.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\190.df29a9454a3f2f20be87bc2d1a3c7d9e.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\194.12565_thumbnail.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\195.8d294db094c73cdf1b059fa455d14ab4.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\196.imgrc0070357600.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\197.22206_T2.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\198.899fc5a28909ed9128457856dd64c689.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\199.12740_2010_0703_IMG_0019.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\2.maxresdefault.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\20.IMG_2771_20170628163729d9d.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\203.73ac275b5d0028bd19ebc7254d30d17d.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\204.DgguJu0UwAAEOPi.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\208.p7070024.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\21.5cb1b5797be36f0745ec1183e0d3e003.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\212.06005_2013_0719_IMG_9571.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\22.DC049805_photo01.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\227.abb99196.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\228.sakuranbo-syrupduke2.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\229._1_image_size_372_x.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\23.05868_2013_0718_IMG_0631.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\230.0f716eb41c3119db9f798c4dc8f975b2.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\233.2627961_1_a.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\234.90466659.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\235.yellowcherry4.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\24.056823_2.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\25.imgrc0070357607.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\253.gasan-top500ga.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\255.Da38uzkUwAEcXtT.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\26.20170822230821474.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\265.a4ba9c717a386b33826d5cd257f04a82.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\269.fodv0000002001_1.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\27.0000073288.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\275.9e530174bf6e46da533b50aa3bb869d6.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\28.IMG_5609-680x510.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\280.cherry_img_002_150409.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\282.gasan-1.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\285.img_f19f3c3160df9e47f711fdf47043c3aa337987.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\29.gr441-i1.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\291.20A161419_1_l.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\292.jag14-05.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\293.32145080.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\294.9ed8df7757697f8b7febb6e5f91a366c.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\297.b2a461e8534836a4f30e053235f6bb9f.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\298.gassan_4l2l_500g_05.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\3.e82bcf746fd86bbd8da5a369ef0e8a79d14f4fef.54.2.9.2.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\30.o0403025313863585762.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\31.092F-002s1.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\32.galtusann1k123.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\33.108-main.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\34.cae463012c1f1310cce9fbab723140855f6ad9d1.19.2.9.2.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\35.17sk-shuset-m.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\36.jgmp6uzaj0i1k68fzzbf.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\37.jag14-100.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\39.o0800104310616239378.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\4.article_art002024_5.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\40.header_sp.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\41.19954407.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\42.main1_gassan_1100_578_578.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\43.331.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\46.sakuranbo_3.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\47.imgrc0070357597.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\5.imgrc0069877892.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\50.yellowcherry2.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\51.200707221215000.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\52.20110807073826274.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\53.004362_b27e6896fccb4ae0b83570b8a1c5ba45.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\54.51IUgar92rL._SX300_QL70_.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\55.1465523441.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\57.20040716gassan.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\58.c817-img01.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\59.13097894441.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\6.ffc89c6fb469660a7cf3e8d05d6f66e1.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\60.04.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\63.20150627_02.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\64.o1080108014782455491.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\66.image.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\68.gassann3tu.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\69.0000080685.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\7.gassan0705.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\70.2syoku2kg.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\71.330.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\72.CnN9jpuXEAEpN4J.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\74.IMG_1408-e1531198041372.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\75.gassannisiki.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\77.main1__Z9Q6958_578_578.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\78.119643427.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\79.category-gassa01.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\8.imgrc0067837626.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\80.IMG_5997.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\81.17sk-shuset-i2.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\85.051F-845.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\86.NE275_0001458.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\87.FG0702c1.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\88.gassan_nishiki2.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\89.chegassan.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\9.imgrc0070357601.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\90.o1080108014782455488.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\91.sakuranbo090620_40421.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\92.090930_kajyu_gassannnisiki-thumb-200x266-2102.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\93.60261868.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\94.czMjYXJ0aWNsZSMzNTA0MyMxMzcyMTkjMzUwNDNfT0JTaWR0dkFjbC5qcGc.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\2_月山錦\99.df11dc831f8d5a6811033aa9da399600-533x400.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\3_大将錦\1.taisyounishiki.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\3_大将錦\102.18471.1.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\3_大将錦\104.sakura2018_7_02.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\3_大将錦\107.taisyounisiki1k1.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\3_大将錦\10_imgrc0073879067.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\3_大将錦\11.%E8%BE%B2%E5%9C%92%E9%96%8B%E7%99%BA%E3%81%AE%E5%A4%A7%E5%B0%86%E9%8C%A6%E7%94%BB%E5%83%8F.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\3_大将錦\112.20110518taisilyou-02.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\3_大将錦\114.main1_taishou_2L_2P_274_274.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\3_大将錦\116.sakura2018_6_02.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\3_大将錦\11_azimiya_sk-143.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\3_大将錦\12.tai05.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\3_大将錦\120.20110518taisilyou-10.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\3_大将錦\12_Y311380AS4.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\3_大将錦\130.taisyouhaltusyou650.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\3_大将錦\134.20110518taisilyou-08.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\3_大将錦\136.img61131415.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\3_大将錦\138.taisyounisiki1k6.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\3_大将錦\13_f0198186_21001290.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\3_大将錦\14.maxresdefault.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\3_大将錦\140.taisyounisiki500g1.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\3_大将錦\143.20537.1.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\3_大将錦\144.pc-yj-och-k1.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\3_大将錦\145.slider-taisho.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\3_大将錦\147.summer_2018_4_02.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\3_大将錦\14_20537.2.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\3_大将錦\15.hqdefault.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\3_大将錦\15_main-image1.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\3_大将錦\16_070711.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\3_大将錦\171.20110518taisilyou-11.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\3_大将錦\17_pd_20388656066956838bf8de0cde07960947bc2800.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\3_大将錦\18_0da333e3.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\3_大将錦\199.main-image2.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\3_大将錦\19_106744336_3637933119554763_7813139621275447582_n.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\3_大将錦\1_.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\3_大将錦\20_JAG-114.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\3_大将錦\21_20200705_ffb8a2.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\3_大将錦\227.540staisho-mainimg.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\3_大将錦\22_image_16.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\3_大将錦\23.img57545567.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\3_大将錦\239.2020-7-l-500g.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\3_大将錦\23_1532.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\3_大将錦\246.530staisho01-img.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\3_大将錦\24_e0154682_22162438.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\3_大将錦\254.20110518taisilyou-09.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\3_大将錦\25_1-2.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\3_大将錦\26_fff5defc58.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\3_大将錦\272.taisyounisiki600405.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\3_大将錦\276.taisho01.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\3_大将錦\27_IMG_5796.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\3_大将錦\28_sn_2_3.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\3_大将錦\29.taishonishiki2.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\3_大将錦\29_sn_2L4.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\3_大将錦\2_20110518taisilyou-04.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\3_大将錦\3.taisyo.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\3_大将錦\30_10877_2018_0628_IMG_9993.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\3_大将錦\31_10878_2018_0628_IMG_9995.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\3_大将錦\32_10866_2018_0628_IMG_0004.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\3_大将錦\33_10864_2018_0628_IMG_0002.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\3_大将錦\34_o2048153614494947195.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\3_大将錦\35_116870535_762202251272506_4728607048528841448_n.jpg
# \\172.18.21.187\aiコンテスト2020\100_開発\学習データ\混合データ\品種\image\7_さくらんぼ\3_大将錦\36_d2ac963c1e140f2c2e5b844b237937b7.jpg
# cannot identify image file '\\\\172.18.21.187\\aiコンテスト2020\\100_開発\\学習データ\\混合データ\\品種\\image\\7_さくらんぼ\\3_大将錦\\36_d2ac963c1e140f2c2e5b844b237937b7.jpg'
# ['\\\\172.18.21.187\\aiコンテスト2020\\100_開発\\学習データ\\混合データ\\品種\\image\\7_さくらんぼ\\3_大将錦\\36_d2ac963c1e140f2c2e5b844b237937b7.jpg']
# 1
