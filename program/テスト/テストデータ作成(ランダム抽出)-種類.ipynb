# %% [markdown]
# # テストデータをランダムにフォルダから抽出して作成する

# %% [markdown]
# ## モジュールインポート

# %%
import os, glob, shutil, random

# %% [markdown]
# ## 定数宣言

# %%
target_dir = '../train_set/学習データ/479削除データ'
output_dir = '../テストデータ'
class_file = 'model_data/種類モデル/class.txt'
fileNum = 100

# %%
img_path = os.path.join(target_dir, 'image')
test_dir = os.path.join(output_dir, '種類', 'random_'+str(fileNum))

# %% [markdown]
# ## クラスファイル取得

# %%
class_list = []
with open(class_file, 'r') as f:
    line = f.readline()
    while line:
        class_list.append(line.replace("\n", ""))
        line = f.readline()

# %%
print(class_list)
# Out:
# ['リンゴ', '梨', 'ミカン', 'イチゴ', 'ブドウ', '桃', 'さくらんぼ']

# %% [markdown]
# ## データをコピー

# %%
img_list =  glob.glob(os.path.join(target_dir, '**', '*.jpg'), recursive=True)
random.shuffle(img_list)
img_list = img_list[:fileNum]

# %%
if not os.path.isdir(test_dir):
    print("folder made:", test_dir)
    os.makedirs(test_dir)
    os.mkdir(os.path.join(test_dir, "image"))
    os.mkdir(os.path.join(test_dir, "annotation"))
    
test_list = []
for img in img_list:
    img_name = os.path.basename(img)
    output_img = os.path.join(test_dir, "image", img_name)
    shutil.copyfile(img, output_img)
    print("copy", img, "to", output_img)
    
    annotation = img.replace("image", "annotation").replace(".jpg", ".txt")
    annotation_name = os.path.basename(annotation)
    output_annotation = os.path.join(test_dir, "annotation", annotation_name)
    shutil.copyfile(annotation, output_annotation)
    print("copy", annotation, "to", output_annotation)
    with open(annotation, 'r') as f:
        line =  f.readline()
        while line:
            annotation = line.split(" ")
            x_min = annotation[0]
            x_max = annotation[1]
            y_min = annotation[2]
            y_max = annotation[3]
            annotation = ",".join([x_min, y_min, x_max, y_max])
            line = f.readline()
    
   
    
    class_index = None
    for c in class_list:
        if img.find(c) > 0:
            class_index = str(class_list.index(c))
            
    test_list.append([output_img, annotation, class_index])
    
last = test_list[-1]
test_file = os.path.join(test_dir,'test.txt')
with open(test_file, 'w', encoding='utf-8') as f:
    for test in test_list:
        jpg = test[0]
        f.write(jpg+ ' ')
        test[1] = test[1].split(" ")
        test[1] = ",".join(test[1])
        f.write(test[1])
        f.write(","+test[2])
        if test != last:
            f.write("\n")
print("file made:", test_file)
# Out:
# folder made: ../テストデータ/種類/random_100
# copy ../train_set/学習データ/479削除データ/image/4_イチゴ/29_紅ほっぺ/954.jpg to ../テストデータ/種類/random_100/image/954.jpg
# copy ../train_set/学習データ/479削除データ/annotation/4_イチゴ/29_紅ほっぺ/954.txt to ../テストデータ/種類/random_100/annotation/954.txt
# copy ../train_set/学習データ/479削除データ/image/3_ミカン/17_麗紅/555.jpg to ../テストデータ/種類/random_100/image/555.jpg
# copy ../train_set/学習データ/479削除データ/annotation/3_ミカン/17_麗紅/555.txt to ../テストデータ/種類/random_100/annotation/555.txt
# copy ../train_set/学習データ/479削除データ/image/2_梨/12_幸水/318.jpg to ../テストデータ/種類/random_100/image/318.jpg
# copy ../train_set/学習データ/479削除データ/annotation/2_梨/12_幸水/318.txt to ../テストデータ/種類/random_100/annotation/318.txt
# copy ../train_set/学習データ/479削除データ/image/7_さくらんぼ/43_月山錦/1385.jpg to ../テストデータ/種類/random_100/image/1385.jpg
# copy ../train_set/学習データ/479削除データ/annotation/7_さくらんぼ/43_月山錦/1385.txt to ../テストデータ/種類/random_100/annotation/1385.txt
# copy ../train_set/学習データ/479削除データ/image/5_ブドウ
jpg
# copy ../train_set/学習データ/479削除データ/annotation/6_桃/39_川中島白桃/1271.txt to ../テストデータ/種類/random_100/annotation/1271.txt
# copy ../train_set/学習データ/479削除データ/image/3_ミカン/18_晩白柚/580.jpg to ../テストデータ/種類/random_100/image/580.jpg
# copy ../train_set/学習データ/479削除データ/annotation/3_ミカン/18_晩白柚/580.txt to ../テストデータ/種類/random_100/annotation/580.txt
# copy ../train_set/学習データ/479削除データ/image/1_リンゴ/4_シナノスイート/101.jpg to ../テストデータ/種類/random_100/image/101.jpg
# copy ../train_set/学習データ/479削除データ/annotation/1_リンゴ/4_シナノスイート/101.txt to ../テストデータ/種類/random_100/annotation/101.txt
# copy ../train_set/学習データ/479削除データ/image/2_梨/14_新高梨/402.jpg to ../テストデータ/種類/random_100/image/402.jpg
# copy ../train_set/学習データ/479削除データ/annotation/2_梨/14_新高梨/402.txt to ../テストデータ/種類/random_100/annotation/402.txt
# copy ../train_set/学習データ/479削除データ/image/3_ミカン/19_安政柑/624.jpg to ../テストデータ/種類/random_100/image/624.jpg
# copy ../train_set/学習データ/479削除データ/annotation/3_ミカン/19_安政柑/624.txt to ../テストデータ/種類/random_100/annotation/624.txt
# copy ../train_set/学習データ/479削除データ/image/1_リンゴ/1_あいかの香り/19.jpg to ../テストデータ/種類/random_100/image/19.jpg
# copy ../train_set/学習データ/479削除データ/annotation/1_リンゴ/1_あいかの香り/19.txt to ../テストデータ/種類/random_100/annotation/19.txt
# copy ../train_set/学習データ/479削除データ/image/3_ミカン/17_麗紅/531.jpg to ../テストデータ/種類/random_100/image/531.jpg
# copy ../train_set/学習データ/479削除データ/annotation/3_ミカン/17_麗紅/531.txt to ../テストデータ/種類/random_100/annotation/531.txt
# copy ../train_set/学習データ/479削除データ/image/6_桃/39_川中島白桃/1280.jpg to ../テストデータ/種類/random_100/image/1280.jpg
# copy ../train_set/学習データ/479削除データ/annotation/6_桃/39_川中島白桃/1280.txt to ../テストデータ/種類/random_100/annotation/1280.txt
# copy ../train_set/学習データ/479削除データ/image/6_桃/41_なつっこ/1334.jpg to ../テストデータ/種類/random_100/image/1334.jpg
# copy ../train_set/学習データ/479削除データ/annotation/6_桃/41_なつっこ/1334.txt to ../テストデータ/種類/random_100/annotation/1334.txt
# copy ../train_set/学習データ/479削除データ/image/3_ミカン/18_晩白柚/571.jpg to ../テストデータ/種類/random_100/image/571.jpg
# copy ../train_set/学習データ/479削除データ/annotation/3_ミカン/18_晩白柚/571.txt to ../テストデータ/種類/random_100/annotation/571.txt
# copy ../train_set/学習データ/479削除データ/image/6_桃/38_あかつき/1221.jpg to ../テストデータ/種類/random_100/image/1221.jpg
# copy ../train_set/学習データ/479削除データ/annotation/6_桃/38_あかつき/1221.txt to ../テストデータ/種類/random_100/annotation/1221.txt
# copy ../train_set/学習データ/479削除データ/image/2_梨/10_秋麗/273.jpg to ../テストデータ/種類/random_100/image/273.jpg
# copy ../train_set/学習データ/479削除データ/annotation/2_梨/10_秋麗/273.txt to ../テストデータ/種類/random_100/annotation/273.txt
# copy ../train_set/学習データ/479削除データ/image/2_梨/13_愛宕梨/375.jpg to ../テストデータ/種類/random_100/image/375.jpg
# copy ../train_set/学習データ/479削除データ/annotation/2_梨/13_愛宕梨/375.txt to ../テストデータ/種類/random_100/annotation/375.txt
# copy ../train_set/学習データ/479削除データ/image/6_桃/39_川中島白桃/1258.jpg to ../テストデータ/種類/random_100/image/1258.jpg
# copy ../train_set/学習データ/479削除データ/annotation/6_桃/39_川中島白桃/1258.txt to ../テストデータ/種類/random_100/annotation/1258.txt
# copy ../train_set/学習データ/479削除データ/image/3_ミカン/21_はるみ/687.jpg to ../テストデータ/種類/random_100/image/687.jpg
# copy ../train_set/学習データ/479削除データ/annotation/3_ミカン/21_はるみ/687.txt to ../テストデータ/種類/random_100/annotation/687.txt
# copy ../train_set/学習データ/479削除データ/image/1_リンゴ/7_星の金貨/202.jpg to ../テストデータ/種類/random_100/image/202.jpg
# copy ../train_set/学習データ/479削除データ/annotation/1_リンゴ/7_星の金貨/202.txt to ../テストデータ/種類/random_100/annotation/202.txt
# copy ../train_set/学習データ/479削除データ/image/4_イチゴ/24_スカイベリー/789.jpg to ../テストデータ/種類/random_100/image/789.jpg
# copy ../train_set/学習データ/479削除データ/annotation/4_イチゴ/24_スカイベリー/789.txt to ../テストデータ/種類/random_100/annotation/789.txt
# copy ../train_set/学習データ/479削除データ/image/5_ブドウ/32_巨峰/1048.jpg to ../テストデータ/種類/random_100/image/1048.jpg
# copy ../train_set/学習データ/479削除データ/annotation/5_ブドウ/32_巨峰/1048.txt to ../テストデータ/種類/random_100/annotation/1048.txt
# copy ../train_set/学習データ/479削除データ/image/4_イチゴ/26_淡雪/843.jpg to ../テストデータ/種類/random_100/image/843.jpg
# copy ../train_set/学習データ/479削除データ/annotation/4_イチゴ/26_淡雪/843.txt to ../テストデータ/種類/random_100/annotation/843.txt
# copy ../train_set/学習データ/479削除データ/image/7_さくらんぼ/43_月山錦/1396.jpg to ../テストデータ/種類/random_100/image/1396.jpg
# copy ../train_set/学習データ/479削除データ/annotation/7_さくらんぼ/43_月山錦/1396.txt to ../テストデータ/種類/random_100/annotation/1396.txt
# copy ../train_set/学習データ/479削除データ/image/1_リンゴ/6_シナノゴールド/170.jpg to ../テストデータ/種類/random_100/image/170.jpg
# copy ../train_set/学習データ/479削除データ/annotation/1_リンゴ/6_シナノゴールド/170.txt to ../テストデータ/種類/random_100/annotation/170.txt
# copy ../train_set/学習データ/479削除データ/image/5_ブドウ/31_デラウェア/996.jpg to ../テストデータ/種類/random_100/image/996.jpg
# copy ../train_set/学習データ/479削除データ/annotation/5_ブドウ/31_デラウェア/996.txt to ../テストデータ/種類/random_100/annotation/996.txt
# copy ../train_set/学習データ/479削除データ/image/5_ブドウ/34_安芸クイーン/1093.jpg to ../テストデータ/種類/random_100/image/1093.jpg
# copy ../train_set/学習データ/479削除データ/annotation/5_ブドウ/34_安芸クイーン/1093.txt to ../テストデータ/種類/random_100/annotation/1093.txt
# copy ../train_set/学習データ/479削除データ/image/4_イチゴ/25_パールホワイト/805.jpg to ../テストデータ/種類/random_100/image/805.jpg
# copy ../train_set/学習データ/479削除データ/annotation/4_イチゴ/25_パールホワイト/805.txt to ../テストデータ/種類/random_100/annotation/805.txt
# copy ../train_set/学習データ/479削除データ/image/5_ブドウ/32_巨峰/1020.jpg to ../テストデータ/種類/random_100/image/1020.jpg
# copy ../train_set/学習データ/479削除データ/annotation/5_ブドウ/32_巨峰/1020.txt to ../テストデータ/種類/random_100/annotation/1020.txt
# copy ../train_set/学習データ/479削除データ/image/5_ブドウ/35_ゴルビー/1146.jpg to ../テストデータ/種類/random_100/image/1146.jpg
# copy ../train_set/学習データ/479削除データ/annotation/5_ブドウ/35_ゴルビー/1146.txt to ../テストデータ/種類/random_100/annotation/1146.txt
# copy ../train_set/学習データ/479削除データ/image/5_ブドウ/32_巨峰/1040.jpg to ../テストデータ/種類/random_100/image/1040.jpg
# copy ../train_set/学習データ/479削除データ/annotation/5_ブドウ/32_巨峰/1040.txt to ../テストデータ/種類/random_100/annotation/1040.txt
# copy ../train_set/学習データ/479削除データ/image/6_桃/38_あかつき/1238.jpg to ../テストデータ/種類/random_100/image/1238.jpg
# copy ../train_set/学習データ/479削除データ/annotation/6_桃/38_あかつき/1238.txt to ../テストデータ/種類/random_100/annotation/1238.txt
# copy ../train_set/学習データ/479削除データ/image/5_ブドウ/32_巨峰/1027.jpg to ../テストデータ/種類/random_100/image/1027.jpg
# copy ../train_set/学習データ/479削除データ/annotation/5_ブドウ/32_巨峰/1027.txt to ../テストデータ/種類/random_100/annotation/1027.txt
# copy ../train_set/学習データ/479削除データ/image/3_ミカン/16_八朔/500.jpg to ../テストデータ/種類/random_100/image/500.jpg
# copy ../train_set/学習データ/479削除データ/annotation/3_ミカン/16_八朔/500.txt to ../テストデータ/種類/random_100/annotation/500.txt
# copy ../train_set/学習データ/479削除データ/image/5_ブドウ/36_ルビーロマン/1179.jpg to ../テストデータ/種類/random_100/image/1179.jpg
# copy ../train_set/学習データ/479削除データ/annotation/5_ブドウ/36_ルビーロマン/1179.txt to ../テストデータ/種類/random_100/annotation/1179.txt
# copy ../train_set/学習データ/479削除データ/image/7_さくらんぼ/45_紅秀峰/1483.jpg to ../テストデータ/種類/random_100/image/1483.jpg
# copy ../train_set/学習データ/479削除データ/annotation/7_さくらんぼ/45_紅秀峰/1483.txt to ../テストデータ/種類/random_100/annotation/1483.txt
# copy ../train_set/学習データ/479削除データ/image/2_梨/10_秋麗/267.jpg to ../テストデータ/種類/random_100/image/267.jpg
# copy ../train_set/学習データ/479削除データ/annotation/2_梨/10_秋麗/267.txt to ../テストデータ/種類/random_100/annotation/267.txt
# copy ../train_set/学習データ/479削除データ/image/7_さくらんぼ/45_紅秀峰/1455.jpg to ../テストデータ/種類/random_100/image/1455.jpg
# copy ../train_set/学習データ/479削除データ/annotation/7_さくらんぼ/45_紅秀峰/1455.txt to ../テストデータ/種類/random_100/annotation/1455.txt
# copy ../train_set/学習データ/479削除データ/image/1_リンゴ/1_あいかの香り/4.jpg to ../テストデータ/種類/random_100/image/4.jpg
# copy ../train_set/学習データ/479削除データ/annotation/1_リンゴ/1_あいかの香り/4.txt to ../テストデータ/種類/random_100/annotation/4.txt
# copy ../train_set/学習データ/479削除データ/image/6_桃/40_まどか/1306.jpg to ../テストデータ/種類/random_100/image/1306.jpg
# copy ../train_set/学習データ/479削除データ/annotation/6_桃/40_まどか/1306.txt to ../テストデータ/種類/random_100/annotation/1306.txt
# copy ../train_set/学習データ/479削除データ/image/6_桃/39_川中島白桃/1255.jpg to ../テストデータ/種類/random_100/image/1255.jpg
# copy ../train_set/学習データ/479削除データ/annotation/6_桃/39_川中島白桃/1255.txt to ../テストデータ/種類/random_100/annotation/1255.txt
# copy ../train_set/学習データ/479削除データ/image/5_ブドウ/34_安芸クイーン/1114.jpg to ../テストデータ/種類/random_100/image/1114.jpg
# copy ../train_set/学習データ/479削除データ/annotation/5_ブドウ/34_安芸クイーン/1114.txt to ../テストデータ/種類/random_100/annotation/1114.txt
# copy ../train_set/学習データ/479削除データ/image/7_さくらんぼ/44_大将錦/1436.jpg to ../テストデータ/種類/random_100/image/1436.jpg
# copy ../train_set/学習データ/479削除データ/annotation/7_さくらんぼ/44_大将錦/1436.txt to ../テストデータ/種類/random_100/annotation/1436.txt
# copy ../train_set/学習データ/479削除データ/image/6_桃/38_あかつき/1236.jpg to ../テストデータ/種類/random_100/image/1236.jpg
# copy ../train_set/学習データ/479削除データ/annotation/6_桃/38_あかつき/1236.txt to ../テストデータ/種類/random_100/annotation/1236.txt
# copy ../train_set/学習データ/479削除データ/image/2_梨/13_愛宕梨/359.jpg to ../テストデータ/種類/random_100/image/359.jpg
# copy ../train_set/学習データ/479削除データ/annotation/2_梨/13_愛宕梨/359.txt to ../テストデータ/種類/random_100/annotation/359.txt
# copy ../train_set/学習データ/479削除データ/image/7_さくらんぼ/43_月山錦/1403.jpg to ../テストデータ/種類/random_100/image/1403.jpg
# copy ../train_set/学習データ/479削除データ/annotation/7_さくらんぼ/43_月山錦/1403.txt to ../テストデータ/種類/random_100/annotation/1403.txt
# copy ../train_set/学習データ/479削除データ/image/7_さくらんぼ/42_佐藤錦/1370.jpg to ../テストデータ/種類/random_100/image/1370.jpg
# copy ../train_set/学習データ/479削除データ/annotation/7_さくらんぼ/42_佐藤錦/1370.txt to ../テストデータ/種類/random_100/annotation/1370.txt
# copy ../train_set/学習データ/479削除データ/image/1_リンゴ/4_シナノスイート/114.jpg to ../テストデータ/種類/random_100/image/114.jpg
# copy ../train_set/学習データ/479削除データ/annotation/1_リンゴ/4_シナノスイート/114.txt to ../テストデータ/種類/random_100/annotation/114.txt
# copy ../train_set/学習データ/479削除データ/image/3_ミカン/22_さんぽう柑/716.jpg to ../テストデータ/種類/random_100/image/716.jpg
# copy ../train_set/学習データ/479削除データ/annotation/3_ミカン/22_さんぽう柑/716.txt to ../テストデータ/種類/random_100/annotation/716.txt
# copy ../train_set/学習データ/479削除データ/image/1_リンゴ/5_王林/135.jpg to ../テストデータ/種類/random_100/image/135.jpg
# copy ../train_set/学習データ/479削除データ/annotation/1_リンゴ/5_王林/135.txt to ../テストデータ/種類/random_100/annotation/135.txt
# copy ../train_set/学習データ/479削除データ/image/4_イチゴ/27_やよいひめ/887.jpg to ../テストデータ/種類/random_100/image/887.jpg
# copy ../train_set/学習データ/479削除データ/annotation/4_イチゴ/27_やよいひめ/887.txt to ../テストデータ/種類/random_100/annotation/887.txt
# copy ../train_set/学習データ/479削除データ/image/4_イチゴ/25_パールホワイト/795.jpg to ../テストデータ/種類/random_100/image/795.jpg
# copy ../train_set/学習データ/479削除データ/annotation/4_イチゴ/25_パールホワイト/795.txt to ../テストデータ/種類/random_100/annotation/795.txt
# copy ../train_set/学習データ/479削除データ/image/7_さくらんぼ/46_南陽/1494.jpg to ../テストデータ/種類/random_100/image/1494.jpg
# copy ../train_set/学習データ/479削除データ/annotation/7_さくらんぼ/46_南陽/1494.txt to ../テストデータ/種類/random_100/annotation/1494.txt
# copy ../train_set/学習データ/479削除データ/image/6_桃/38_あかつき/1249.jpg to ../テストデータ/種類/random_100/image/1249.jpg
# copy ../train_set/学習データ/479削除データ/annotation/6_桃/38_あかつき/1249.txt to ../テストデータ/種類/random_100/annotation/1249.txt
# copy ../train_set/学習データ/479削除データ/image/7_さくらんぼ/43_月山錦/1400.jpg to ../テストデータ/種類/random_100/image/1400.jpg
# copy ../train_set/学習データ/479削除データ/annotation/7_さくらんぼ/43_月山錦/1400.txt to ../テストデータ/種類/random_100/annotation/1400.txt
# copy ../train_set/学習データ/479削除データ/image/1_リンゴ/8_金星/238.jpg to ../テストデータ/種類/random_100/image/238.jpg
# copy ../train_set/学習データ/479削除データ/annotation/1_リンゴ/8_金星/238.txt to ../テストデータ/種類/random_100/annotation/238.txt
# copy ../train_set/学習データ/479削除データ/image/3_ミカン/15_青島ミカン/468.jpg to ../テストデータ/種類/random_100/image/468.jpg
# copy ../train_set/学習データ/479削除データ/annotation/3_ミカン/15_青島ミカン/468.txt to ../テストデータ/種類/random_100/annotation/468.txt
# copy ../train_set/学習データ/479削除データ/image/5_ブドウ/32_巨峰/1045.jpg to ../テストデータ/種類/random_100/image/1045.jpg
# copy ../train_set/学習データ/479削除データ/annotation/5_ブドウ/32_巨峰/1045.txt to ../テストデータ/種類/random_100/annotation/1045.txt
# copy ../train_set/学習データ/479削除データ/image/4_イチゴ/25_パールホワイト/822.jpg to ../テストデータ/種類/random_100/image/822.jpg
# copy ../train_set/学習データ/479削除データ/annotation/4_イチゴ/25_パールホワイト/822.txt to ../テストデータ/種類/random_100/annotation/822.txt
# file made: ../テストデータ/種類/random_100/test.txt
